# %%
import pandas as pd

# %%
link = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/을지로동_link.csv', encoding='euc-kr')
node = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/을지로동_node.csv', encoding='euc-kr')

# %%
link
# Out:
#       link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 0   478700386     222614     343922          0          0         60
# 1   478700473     340758     222911     222911     340758         60
# 2   478700847     222614     343321          0          0         50
# 3   478702212     222615     223364     223364     222615         60
# 4   478702231     221695     223366     223366     221695         60
# ..        ...        ...        ...        ...        ...        ...
# 62  571723742     343922     340739          0          0         60
# 63  571725265     340785     340784          0          0         60
# 64  571725267     342911     344049     344049     342911         60
# 65  571742588     614011     343309          0          0          0
# 66  571742589     614011     340796          0          0         50
#
#    road_name  road_no  road_rank  link_type  ...    up_v_link    dw_v_link  \
# ...

# %%
node
# Out:
#     node_id  node_type node_name  tra_light  toll_id  num_link           x  \
# 0    221695        101    중부경찰서앞          3        0         4  954959.537
# 1    221699        101    을지로3가역          3        0         4  954940.277
# 2    221702        101      청계4가          3        0         4  955664.007
# 3    221705        101       NaN          0        0         3  954924.800
# 4    222614        101      청계4가          3        0         4  955665.437
# 5    222615        101     명보사거리          4        0         4  955213.967
# 6    222616        101     을지로3가          4        0         4  955193.818
# 7    222617        101      청계3가          3        0         4  955174.207
# 8    222618        101      청계3가          4        0         4  955171.715
# 9    222911        101     을지로4가          0        0         3  955611.513
# 10   223252        103       NaN          0        0         2  955207.941
# ...

# %%
link_inter = link[link['link_type'] == 4]
link_inter
# Out:
#       link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 1   478700473     340758     222911     222911     340758         60
# 17  478703267     343126     222911          0          0         30
# 39  571704897     340590     340758     340758     340590         60
# 40  571704957     340590     340591          0          0         30
# 41  571704966     340739     340591          0          0         60
# 42  571704969     340591     340758          0          0         60
# 46  571715261     340739     343126          0          0         30
# 48  571716367     343268     343269          0          0          0
# 49  571716368     343269     343270          0          0          0
# 50  571716369     343270     343271          0          0          0
# 51  571716370     343271     343268          0          0          0
# 52  571716371     340759     343268     343268     340759         60
# 54  571716374     340759     343269     343269     340759         60
# ...
