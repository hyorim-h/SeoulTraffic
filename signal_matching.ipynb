# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import os

# %%
m = pd.read_csv('D:/서울시신호/데이터/신호주기(한양도성)/DB/명보사거리_20190612.csv')
m
# Out:
#               시간  TOD  패턴  현시  연동  주기      기준  좌회전신호  비보호좌회전신호  직진신호  적색신호  \
# 0        0:00:00    1   1   1   1  80   을지로3가      0         0     0     1
# 1        0:00:01    1   1   1   1  80   을지로3가      0         0     0     1
# 2        0:00:02    1   1   1   1  80   을지로3가      0         0     0     1
# 3        0:00:03    1   1   1   1  80   을지로3가      0         0     0     1
# 4        0:00:04    1   1   1   1  80   을지로3가      0         0     0     1
# ...          ...  ...  ..  ..  ..  ..     ...    ...       ...   ...   ...
# 345595  23:59:55    1   4   2   1  80  호텔피제이앞      0         0     0     1
# 345596  23:59:56    1   4   2   1  80  호텔피제이앞      0         0     0     1
# 345597  23:59:57    1   4   2   1  80  호텔피제이앞      0         0     0     1
# 345598  23:59:58    1   4   2   1  80  호텔피제이앞      0         0     0     1
# 345599  23:59:59    1   4   2   1  80  호텔피제이앞      0         0     0     1
#
#         황색신호  보행신호     기준link
# 0          0     0  478702550
# ...

# %%
j = pd.read_csv('D:/서울시신호/데이터/신호주기(한양도성)/DB/중구청_20210409_TOD1.csv', encoding='euc-kr')
j
# Out:
#              시간  TOD  패턴  현시  연동   주기      기준  좌회전신호  직진신호  적색신호  ...  \
# 0       6:00:00    4   1   1  67  110   을지로4가      0     0     1  ...
# 1       6:00:01    4   1   1  67  110   을지로4가      1     1     0  ...
# 2       6:00:02    4   1   1  67  110   을지로4가      1     1     0  ...
# 3       6:00:03    4   1   1  67  110   을지로4가      1     1     0  ...
# 4       6:00:04    4   1   1  67  110   을지로4가      1     1     0  ...
# ...         ...  ...  ..  ..  ..  ...     ...    ...   ...   ...  ...
# 345595  5:59:55    4   2   3   1  110  오장동사거리      0     0     1  ...
# 345596  5:59:56    4   2   3   1  110  오장동사거리      0     0     1  ...
# 345597  5:59:57    4   2   3   1  110  오장동사거리      0     0     1  ...
# 345598  5:59:58    4   2   3   1  110  오장동사거리      0     0     1  ...
# 345599  5:59:59    4   2   3   1  110  오장동사거리      0     0     1  ...
#
#         비보호좌회전신호     기준link  보행자좌회전상충  보행자직진상충  보행자우회전상충  보행자비보호좌회전상충  \
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345600 entries, 0 to 345599
# Data columns (total 14 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시간        345600 non-null  object
#  1   TOD       345600 non-null  int64
#  2   패턴        345600 non-null  int64
#  3   현시        345600 non-null  int64
#  4   연동        345600 non-null  int64
#  5   주기        345600 non-null  int64
#  6   기준        345600 non-null  object
#  7   좌회전신호     345600 non-null  int64
#  8   비보호좌회전신호  345600 non-null  int64
#  9   직진신호      345600 non-null  int64
#  10  적색신호      345600 non-null  int64
#  11  황색신호      345600 non-null  int64
#  12  보행신호      345600 non-null  int64
#  13  기준link    345600 non-null  int64
# dtypes: int64(12), object(2)
# memory usage: 36.9+ MB

# %%
j[j['기준'] == '호텔피제이앞']
# Out:
#              시간  TOD  패턴  현시  연동   주기      기준  좌회전신호  직진신호  적색신호  ...  \
# 86400   6:00:00    4   1   1  67  110  호텔피제이앞      0     0     1  ...
# 86401   6:00:01    4   1   1  67  110  호텔피제이앞      0     0     1  ...
# 86402   6:00:02    4   1   1  67  110  호텔피제이앞      0     0     1  ...
# 86403   6:00:03    4   1   1  67  110  호텔피제이앞      0     0     1  ...
# 86404   6:00:04    4   1   1  67  110  호텔피제이앞      0     0     1  ...
# ...         ...  ...  ..  ..  ..  ...     ...    ...   ...   ...  ...
# 172795  5:59:55    4   2   3   1  110  호텔피제이앞      0     0     1  ...
# 172796  5:59:56    4   2   3   1  110  호텔피제이앞      0     0     1  ...
# 172797  5:59:57    4   2   3   1  110  호텔피제이앞      0     0     1  ...
# 172798  5:59:58    4   2   3   1  110  호텔피제이앞      0     0     1  ...
# 172799  5:59:59    4   2   3   1  110  호텔피제이앞      0     0     1  ...
#
#         비보호좌회전신호     기준link  보행자좌회전상충  보행자직진상충  보행자우회전상충  보행자비보호좌회전상충  \
# ...

# %%
m['시간'][0]
# Out:
# '0:00:00'

# %%
j['시간'][0]
# Out:
# '6:00:00'

# %%
header = ['p_reqdate', 'trip_init_session_id', 'mesh_cd', 'link_id', 'link_dir', 'gps_x', 'gps_y', 'gps_tm', 'speed_gps', 
          'altitude', 'angle', 'depart_name', 'dest_name', 'dest_poiid', 'dest_x', 'dest_y', 'cb_name', 'car_model', 'car_fuel', 'car_displacement', 'car_modelYear']

# %%
df = pd.read_csv('J:/티맵포인트/part-00000-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv', header=None)
df.columns = header
df
# Out:
#        p_reqdate      trip_init_session_id  mesh_cd  link_id  link_dir  \
# 0       20220411  105020220411021525933S00     5717     6797         0
# 1       20220411  105020220411052621740S00     5717    43485         0
# 2       20220411  105020220411052621740S00     5717    43485         0
# 3       20220411  105020220411052621740S00     5717    43485         0
# 4       20220411  105020220411052621740S00     5717    43485         0
# ...          ...                       ...      ...      ...       ...
# 51886   20220411  105020220411104813050S00     4787     9562         0
# 51887   20220411  105020220411104813050S00     4787    13002         0
# 51888   20220411  105020220411104813050S00     4787    13002         0
# 51889   20220411  105020220411104813050S00     4787    13002         0
# 51890   20220411  105020220411104813050S00     4787    13002         0
#
#             gps_x      gps_y          gps_tm  speed_gps  altitude  ...  \
# ...

# %%
files = os.listdir('J:/티맵포인트')
files
# Out:
# ['part-00000-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00001-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00002-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00003-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00004-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00005-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00006-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00007-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00008-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00009-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00010-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00011-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00012-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00013-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00014-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
# ...

# %%
df['link_dir'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# files.remove('p_reqdate=20220411.zip')
# files.remove('p_reqdate=20220411.zip.temp')
# files.remove('~$데이터정의서.xlsx')
# files.remove('데이터정의서.xlsx')
files.remove('part-00000-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv')

# %%
files
# Out:
# ['part-00001-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00002-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00003-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00004-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00005-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00006-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00007-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00008-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00009-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00010-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00011-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00012-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00013-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00014-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
#  'part-00015-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv',
# ...

# %%
for file in files:
    tmp = pd.read_csv('J:/티맵포인트/' + file, header=None)
    tmp.columns = header
    print(file)
    df = pd.concat([df, tmp])
# Out:
# part-00001-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00002-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00003-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00004-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00005-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00006-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00007-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00008-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00009-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00010-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00011-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00012-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00013-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00014-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00015-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# part-00016-24cc63dc-c961-47db-bae2-a7b89a52ab6d.c000.csv
# ...

# %%
df
# Out:
#        p_reqdate      trip_init_session_id  mesh_cd  link_id  link_dir  \
# 0       20220411  105020220411021525933S00     5717     6797         0
# 1       20220411  105020220411052621740S00     5717    43485         0
# 2       20220411  105020220411052621740S00     5717    43485         0
# 3       20220411  105020220411052621740S00     5717    43485         0
# 4       20220411  105020220411052621740S00     5717    43485         0
# ...          ...                       ...      ...      ...       ...
# 51903   20220411  355220220411113849962S00     5717    12838         0
# 51904   20220411  355220220411113849962S00     5717    12838         0
# 51905   20220411  355220220411113849962S00     5717    12838         0
# 51906   20220411  355220220411113849962S00     5717    12838         0
# 51907   20220411  355220220411113849962S00     5717    12838         0
#
#             gps_x      gps_y          gps_tm  speed_gps  altitude  ...  \
# ...

# %%
df.to_csv('J:/티맵포인트/p_reqdate=20220411.csv', index=False)

# %%
len(df['trip_init_session_id'].unique())
# Out:
# 18777
