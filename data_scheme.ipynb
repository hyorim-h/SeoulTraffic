# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# row 생략 없이 출력
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('C:/Users/hyorim/Desktop/연구실/[학술용역]서울시신호/TM_링크경로데이터_20211014/TM_P1_POLYGON_20211014.csv',
                 nrows=10000000)

# %%
df.head()
# Out:
#                      obu_id  grp_id  seq    v_link_id              in_time  \
# 0  105920211014000948667S00       1    0           -1  2021-10-14 00:10:53
# 1  105920211014000948667S00       1    1  57171383501  2021-10-14 00:10:54
# 2  105920211014000948667S00       1    2  57170361001  2021-10-14 00:11:08
# 3  105920211014000948667S00       1    3  57170357102  2021-10-14 00:11:15
# 4  105920211014000948667S00       1    4  57170358402  2021-10-14 00:11:46
#
#               out_time  sido_id  sigungu_id   emd_id
# 0  2021-10-14 00:10:53       -1          -1       -1
# 1  2021-10-14 00:11:07    11000       11230  1123077
# 2  2021-10-14 00:11:14    11000       11230  1123077
# 3  2021-10-14 00:11:45    11000       11230  1123078
# 4  2021-10-14 00:12:44    11000       11230  1123078

# %%
df[df['grp_id']!=1]
# Out:
#                            obu_id  grp_id  seq    v_link_id  \
# 6795     108120211014001154018S00       2    0           -1
# 6796     108120211014001154018S00       2    1  57334314401
# 6797     108120211014001154018S00       2    2  57334577202
# 6798     108120211014001154018S00       2    3  57334036102
# 6799     108120211014001154018S00       2    4  57334044301
# ...                           ...     ...  ...          ...
# 9999923  108120211014044133266S00       2   27  65880010901
# 9999924  108120211014044133266S00       2   28  65880016502
# 9999925  108120211014044133266S00       2   29  65880003302
# 9999926  108120211014044133266S00       2   30  65880016601
# 9999927  108120211014044133266S00       2   31           -1
#
#                      in_time             out_time  sido_id  sigungu_id  \
# 6795     2021-10-14 00:40:33  2021-10-14 00:40:33       -1          -1
# 6796     2021-10-14 00:40:34  2021-10-14 00:41:10    31000       31191
# ...

# %%
df[df['obu_id']=='108120211014005217773S00']
# Out:
#                           obu_id  grp_id  seq    v_link_id  \
# 313693  108120211014005217773S00       1    0           -1
# 313694  108120211014005217773S00       1    1  47660313201
# 313695  108120211014005217773S00       1    2  47660313301
# 313696  108120211014005217773S00       1    3  47660313001
# 313697  108120211014005217773S00       1    4  47660312801
# 313698  108120211014005217773S00       1    5  47760991001
# 313699  108120211014005217773S00       1    6  47765913402
# 313700  108120211014005217773S00       1    7  47761186701
# 313701  108120211014005217773S00       1    8           -1
# 313702  108120211014005217773S00       1    9  47660265002
# 313703  108120211014005217773S00       1   10  47660267701
# 313704  108120211014005217773S00       1   11           -1
# 313705  108120211014005217773S00       2    0           -1
# 313706  108120211014005217773S00       2    1  47660267702
# 313707  108120211014005217773S00       2    2  47663207601
# ...

# %%
df.to_csv('D:/[학술용역]서울시신호/data_sample.csv')

# %%
smp = df['v_link_id'].astype(str)
smp
smp.str.endswith('0').value_counts()
# Out:
# False    10000000
# Name: v_link_id, dtype: int64

# %%
seq0 = df[df['seq']==0]
seq0[seq0['v_link_id'] == -1]
# Out:
#                           obu_id  grp_id  seq  v_link_id              in_time  \
# 0       105920211014000948667S00       1    0         -1  2021-10-14 00:10:53
# 22      105820211014001658424S00       1    0         -1  2021-10-14 00:19:23
# 397     105620211014000723525S00       1    0         -1  2021-10-14 00:07:36
# 452     108220211014000404494S00       1    0         -1  2021-10-14 00:05:38
# 592     105820211014003602425S00       1    0         -1  2021-10-14 00:36:46
# ...                          ...     ...  ...        ...                  ...
# 999765  105520211014003925511S00       1    0         -1  2021-10-14 00:40:15
# 999867  108520211014004948920S01       1    0         -1  2021-10-14 00:50:22
# 999889  105520211014000656561S00       1    0         -1  2021-10-14 00:07:05
# 999955  108320211014005846824S00       1    0         -1  2021-10-14 00:58:53
# 999994  105520211014000926880S00       1    0         -1  2021-10-14 00:23:17
#
# ...
