# %%
os.getcwd()

# %%
import pandas as pd
import numpy as np
import os
import geopandas as gpd

# %%
shp_file = 'D:/서울시신호/데이터/GIS/level6_2021년_Shape파일/교차로일부.shp'  # SHP 파일의 경로
df_shp = gpd.read_file(shp_file)

# %%
df_shp
# Out:
#          link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 0    478700031.0   221675.0   221676.0        0.0        0.0        0.0
# 1    478700040.0   221717.0   222809.0   222809.0   221717.0       10.0
# 2    478700041.0   221716.0   222809.0   222809.0   221716.0       10.0
# 3    478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# 4    478700316.0   222611.0   221702.0        0.0        0.0       60.0
# ..           ...        ...        ...        ...        ...        ...
# 758  571742589.0   614011.0   340796.0        0.0        0.0       50.0
# 759  900000170.0   900085.0   221715.0        0.0        0.0       30.0
# 760  900000171.0   563222.0   900085.0        0.0        0.0       30.0
# 761  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 762  478704587.0   223364.0   224072.0   224072.0   223364.0       60.0
#
#     road_name road_no  road_rank  link_type  ...     dw_v_link      m_date  \
# ...

# %%
del csv_file

# %%
import pandas as pd

csv_file = 'C:/users/hyorim/Desktop/df0_result2.csv'  # CSV 파일의 경로
df_csv = pd.read_csv(csv_file)

# %%
len(df_csv.obu_id.unique())
# Out:
# 155

# %%
df_csv.columns
# Out:
# Index(['ETA1', 'link', 'level', 'obu_id'], dtype='object')

# %%
eta1 = df_csv.ETA1.unique()

# %%
sample = df_csv[df_csv['obu_id']=='108620210118162801845S00']
sample.shape
# Out:
# (29, 25)

# %%
sample1700 = df_csv[df_csv['time']=='17:00:00']
sample1715 = df_csv[df_csv['time']=='17:15:00']
sample1730 = df_csv[df_csv['time']=='17:30:00']
sample1745 = df_csv[df_csv['time']=='17:45:00']

# %%
sample1745.shape
# Out:
# (318385, 25)

# %%
sample1700['color']=1
sample1715['color']=1
sample1730['color']=1
sample1745['color']=1
# Out:
# C:\Users\hyorim\AppData\Local\Temp\ipykernel_37356\3772697112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample1700['color']=1
# C:\Users\hyorim\AppData\Local\Temp\ipykernel_37356\3772697112.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample1715['color']=1
# C:\Users\hyorim\AppData\Local\Temp\ipykernel_37356\3772697112.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sample1700_h = sample1700[sample1700['obu_id']=='105020210118164312973S00']

# %%
tmp = sample1700[sample1700.link_id.isin(inter)]
obugrp = tmp[['obu_id', 'group_id']]
obugrp2 = obugrp.drop_duplicates()
obugrp2
# Out:
#                             obu_id  group_id
# 163       108220210118165602438S00         1
# 316       105520210118165023629S01         1
# 450       105020210118164312973S00         1
# 793       105920210118165254651S00         1
# 936       105820210118165721009S01         1
# ...                            ...       ...
# 16712776  105520210124165206929S00         1
# 17457757  108320210124101824559S00         2
# 17726970  108320210124123540255S00         1
# 17847498  108220210124123449693S00         2
# 17883488  105920210124134702973S00         1
#
# [12050 rows x 2 columns]

# %%
df_all = pd.read_csv('C:/users/hyorim/Desktop/df_all.csv')
df_all
# Out:
#         Unnamed: 0.1  Unnamed: 0                    obu_id  group_id veh_type  \
# 0                 41          57  108220211115001649182S01         1       TM
# 1                 41          57  108220211115001649182S01         1       TM
# 2                 41          57  108220211115001649182S01         1       TM
# 3                 41          57  108220211115001649182S01         1       TM
# 4                 41          57  108220211115001649182S01         1       TM
# ...              ...         ...                       ...       ...      ...
# 752819      55959562    68012665  105620211121234217542S00         1       TM
# 752820      55959562    68012665  105620211121234217542S00         1       TM
# 752821      55959562    68012665  105620211121234217542S00         1       TM
# 752822      55959562    68012665  105620211121234217542S00         1       TM
# 752823      55959562    68012665  105620211121234217542S00         1       TM
#
# ...

# %%
eta1 = df_all.ETA1.unique()
eta15 = df_all.time_y.unique()
eta15
# Out:
# array(['00:15:00', '00:00:00', '00:45:00', '00:30:00'], dtype=object)

# %%
df_all_00 = df_all[df_all['time_y']=='00:00:00']
df_all_00
# Out:
#         Unnamed: 0.1  Unnamed: 0                    obu_id  group_id veh_type  \
# 1                 41          57  108220211115001649182S01         1       TM
# 5                 41          57  108220211115001649182S01         1       TM
# 9                 42          58  108220211115001649182S01         1       TM
# 13                42          58  108220211115001649182S01         1       TM
# 17                43          59  108220211115001649182S01         1       TM
# ...              ...         ...                       ...       ...      ...
# 752805      55773116    67782267  105020211121214651124S00         1       TM
# 752809      55773117    67782268  105020211121214651124S00         1       TM
# 752813      55773117    67782268  105020211121214651124S00         1       TM
# 752817      55959562    68012665  105620211121234217542S00         1       TM
# 752821      55959562    68012665  105620211121234217542S00         1       TM
#
# ...

# %%
# 'link_id' 열을 기준으로 조인
merged_df1700 = pd.merge(df_shp, sample1700_h[['link_id', 'color']], how='left', on='link_id')

# %%
merged_df1700
# Out:
#           link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 0     478700031.0   221675.0   221676.0        0.0        0.0        0.0
# 1     478700040.0   221717.0   222809.0   222809.0   221717.0       10.0
# 2     478700041.0   221716.0   222809.0   222809.0   221716.0       10.0
# 3     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# 4     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# ...           ...        ...        ...        ...        ...        ...
# 1351  900000171.0   563222.0   900085.0        0.0        0.0       30.0
# 1352  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1353  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1354  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1355  478704587.0   223364.0   224072.0   224072.0   223364.0       60.0
#
#      road_name road_no  road_rank  link_type  ...  rc_id  rc_name rc_hist  \
# ...

# %%
tmp = df_csv[df_csv['ETA1']==eta1[0]]
pd.merge(df_shp, tmp[['link', 'level']], how='left', left_on='link_id', right_on='link')
# Out:
#           link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 0     478700031.0   221675.0   221676.0        0.0        0.0        0.0
# 1     478700040.0   221717.0   222809.0   222809.0   221717.0       10.0
# 2     478700041.0   221716.0   222809.0   222809.0   221716.0       10.0
# 3     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# 4     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# ...           ...        ...        ...        ...        ...        ...
# 1213  900000171.0   563222.0   900085.0        0.0        0.0       30.0
# 1214  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1215  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1216  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1217  478704587.0   223364.0   224072.0   224072.0   223364.0       60.0
#
#      road_name road_no  road_rank  link_type  ...  rc_id  rc_name rc_hist  \
# ...

# %%
merged_df1700 = pd.merge(df_shp, tmp[['link', 'level']], how='left', left_on='link_id', right_on='link')
merged_df1700
# Out:
#           link_id  up_f_node  up_t_node  dw_f_node  dw_t_node  max_speed  \
# 0     478700031.0   221675.0   221676.0        0.0        0.0        0.0
# 1     478700040.0   221717.0   222809.0   222809.0   221717.0       10.0
# 2     478700041.0   221716.0   222809.0   222809.0   221716.0       10.0
# 3     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# 4     478700312.0   221715.0   222609.0   222609.0   221715.0       60.0
# ...           ...        ...        ...        ...        ...        ...
# 1351  900000171.0   563222.0   900085.0        0.0        0.0       30.0
# 1352  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1353  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1354  928701529.0  1730120.0   222798.0        0.0        0.0       30.0
# 1355  478704587.0   223364.0   224072.0   224072.0   223364.0       60.0
#
#      road_name road_no  road_rank  link_type  ...  rc_id  rc_name rc_hist  \
# ...

# %%
obu = df_all_00.obu_id.unique()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 데이터 불러오기 및 조인 (이전 단계 참조)
# 예: merged_df = ...

# 색상 결정 함수
def color_for_value(value):
    if value == 4:
        return 'red'
    elif value == 3:
        return 'orange'
    elif value == 2:
        return 'yellow'
    elif value == 2:
        return 'green'
    else:
        return 'lightgray'  # 기타 값에 대한 색상 (옵션)

for i in eta1:
    print(i)
    tmp = df_all[df_all['ETA1']==i]
    merged_df1700 = pd.merge(df_shp, tmp[['link', 'level']], how='left', left_on='link_id', right_on='link')
    
    # 색상 적용
    colors = merged_df1700['level'].apply(color_for_value)

    # 지도 그리기
    fig, ax = plt.subplots(figsize=(10, 10))
    merged_df1700.plot(ax=ax, color=colors, alpha=0.5)
    plt.savefig('D:/서울시신호/중간보고/지도/eta1/' + str(i[:2]) + '_' + i[-2:] + '.png')
    # 지도 설정
    ax.set_axis_off()
    # plt.show()
    plt.close()
# Out:
# 00:17
# 00:18
# 00:19
# 00:07
# 00:08
# 00:09
# 00:30
# 00:31
# 00:32
# 00:33
# 00:34
# 00:35
# 00:36
# 00:21
# 00:22
# 00:23
# 00:24
# 00:25
# 00:26
# 00:06
# 00:44
# 00:43
# 00:27
# 00:28
# 00:29
# 00:42
# 00:02
# 00:03
# 00:41
# 00:14
# 00:15
# 00:16
# 00:40
# 00:11
# 00:12
# 00:13
# 00:20
# 00:37
# 00:38
# 00:10
# 00:04
# 00:05
# 00:39
# 00:01
# 00:00

# %%
tmp
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, obu_id, group_id, veh_type, seq, link_id, from_vlink_id, datetime, to_vlink_id, v_link_id, in_time, in_datetime, out_datetime, ETA15, out_time, our_speed, length, speed, emd_code, road_rank, max_speed_x, link_type, road_type, time_x, spd_all, spd, ETA1, max_speed_y, time_y, link, ffst, green, mean, in_datetime2, out_datetime2, timedelta, level]
# Index: []
#
# [0 rows x 38 columns]

# %%
df_all['ETA15']
# Out:
# 0         2021-11-15 00:15:00
# 1         2021-11-15 00:15:00
# 2         2021-11-15 00:15:00
# 3         2021-11-15 00:15:00
# 4         2021-11-15 00:15:00
#                  ...
# 752819    2021-11-22 00:00:00
# 752820    2021-11-22 00:00:00
# 752821    2021-11-22 00:00:00
# 752822    2021-11-22 00:00:00
# 752823    2021-11-22 00:00:00
# Name: ETA15, Length: 752824, dtype: object

# %%
for i in eta15:
    print(i)
    tmp = df_all[df_all['time_y']==i]
    merged_df1700 = pd.merge(df_shp, tmp[['link', 'level']], how='left', left_on='link_id', right_on='link')
    
    # 색상 적용
    colors = merged_df1700['level'].apply(color_for_value)

    # 지도 그리기
    fig, ax = plt.subplots(figsize=(10, 10))
    merged_df1700.plot(ax=ax, color=colors, alpha=0.5)
    plt.savefig('D:/서울시신호/중간보고/지도/eta15/' + str(i[:2]) + '_' + str(i[3:5]) + '.png')
    # 지도 설정
    ax.set_axis_off()
    # plt.show()
    plt.close()
# Out:
# 00:15:00
# 00:00:00
# 00:45:00
# 00:30:00

# %%
df_all_00
# Out:
#         Unnamed: 0.1  Unnamed: 0                    obu_id  group_id veh_type  \
# 1                 41          57  108220211115001649182S01         1       TM
# 5                 41          57  108220211115001649182S01         1       TM
# 9                 42          58  108220211115001649182S01         1       TM
# 13                42          58  108220211115001649182S01         1       TM
# 17                43          59  108220211115001649182S01         1       TM
# ...              ...         ...                       ...       ...      ...
# 752805      55773116    67782267  105020211121214651124S00         1       TM
# 752809      55773117    67782268  105020211121214651124S00         1       TM
# 752813      55773117    67782268  105020211121214651124S00         1       TM
# 752817      55959562    68012665  105620211121234217542S00         1       TM
# 752821      55959562    68012665  105620211121234217542S00         1       TM
#
# ...

# %%
colors.value_counts()
# Out:
# lightgray    649
# red          349
# orange       238
# blue         120
# Name: level, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 10))
merged_df1700.plot(ax=ax, color=colors)
# Out:
# <AxesSubplot: >

# %%
obu.reset_index()
# Out:
#           index                    obu_id
# 0           163  108220210118165602438S00
# 1           316  105520210118165023629S01
# 2           450  105020210118164312973S00
# 3           793  105920210118165254651S00
# 4           936  105820210118165721009S01
# ...         ...                       ...
# 12045  16712776  105520210124165206929S00
# 12046  17457757  108320210124101824559S00
# 12047  17726970  108320210124123540255S00
# 12048  17847498  108220210124123449693S00
# 12049  17883488  105920210124134702973S00
#
# [12050 rows x 2 columns]

# %%
inter = [478700031,478700040,478700041,478700312,478700316,478700368,478700386,478700421,478700422,478700423,478700424,478700425,478700428,478700435,478700437,478700473,478700493,478700524,478700596,478700703,478700721,478700739,478700847,478700879,478700905,478700911,478700914,478700916,478700917,478700919,478701533,478701598,478701605,478701608,478701630,478701632,478701643,478701653,478701656,478702212,478702231,478702327,478702539,478702540,478702543,478702548,478702550,478702552,478702556,478702557,478702560,478702561,478702562,478702563,478702565,478702566,478702569,478702570,478702577,478702580,478702581,478702582,478702816,478702819,478702820,478702862,478702863,478702867,478702868,478702870,478703062,478703071,478703072,478703074,478703267,478703558,478703568,478703569,478