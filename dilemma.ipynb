# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.options.display.float_format = ' {:.5f}'. format
import numpy as np

# %%
df = pd.read_csv('J:/hyorim/회현사거리/회현사거리eastbound.csv', encoding='euc-kr')
df
# Out:
#         obu_id  group_id veh_type   seq            timestamp           x  \
# 0       440146         1       TW   129  2020/10/06 06:00:39  954422.149
# 1       440146         1       TW   124  2020/10/06 06:00:34  954375.045
# 2       440146         1       TW   123  2020/10/06 06:00:33  954366.226
# 3       440146         1       TW   126  2020/10/06 06:00:36  954393.156
# 4       440146         1       TW   125  2020/10/06 06:00:35  954384.008
# ...        ...       ...      ...   ...                  ...         ...
# 45475  4401196         1       TW  1941  2020/10/06 14:28:08  954374.697
# 45476  4401196         1       TW  1940  2020/10/06 14:28:07  954379.057
# 45477   440146         1       TW   128  2020/10/06 06:00:38  954412.209
# 45478   440146         1       TW   127  2020/10/06 06:00:37  954402.552
# 45479   440146         1       TW   130  2020/10/06 06:00:40  954432.377
#
#                  y    spd   acc  type  ...    m_date  rc_id rc_name rc_hist  \
# ...

# %%
df['spd2'] = df['spd']/3.6
df
# Out:
#         obu_id  group_id veh_type   seq            timestamp           x  \
# 0       440146         1       TW   129  2020/10/06 06:00:39  954422.149
# 1       440146         1       TW   124  2020/10/06 06:00:34  954375.045
# 2       440146         1       TW   123  2020/10/06 06:00:33  954366.226
# 3       440146         1       TW   126  2020/10/06 06:00:36  954393.156
# 4       440146         1       TW   125  2020/10/06 06:00:35  954384.008
# ...        ...       ...      ...   ...                  ...         ...
# 45475  4401196         1       TW  1941  2020/10/06 14:28:08  954374.697
# 45476  4401196         1       TW  1940  2020/10/06 14:28:07  954379.057
# 45477   440146         1       TW   128  2020/10/06 06:00:38  954412.209
# 45478   440146         1       TW   127  2020/10/06 06:00:37  954402.552
# 45479   440146         1       TW   130  2020/10/06 06:00:40  954432.377
#
#                  y    spd   acc  type  ...  rc_id  rc_name rc_hist rc_date  \
# ...

# %%
60/3.6
# Out:
# 16.666666666666668

# %%
dilemma = (1 + 16.67/(2*df['acc']) + (51.8 + 5)/16.67 - 5)*16.67
dilemma
# Out:
# 0         545.897800
# 1        1147.990417
# 2        1726.925625
# 3         569.055208
# 4         721.406579
#             ...
# 45475     346.387821
# 45476     469.238793
# 45477     545.897800
# 45478     486.350179
# 45479     545.897800
# Name: acc, Length: 45480, dtype: float64

# %%
dilemma.describe()
# Out:
# count    45480.00000
# mean             NaN
# std              NaN
# min             -inf
# 25%       -357.24113
# 50%       -119.28508
# 75%        257.32087
# max              inf
# Name: acc, dtype: float64

# %%
plt.boxplot(dilemma)
# Out:
# c:\Users\hyorim\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c38c59490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c38c5ac90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c38b67050>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c36a282d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c38c4df10>],
#  'means': []}

# %%
plt.boxplot(df['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c36a94310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c36a95950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c36a8b650>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c36a96f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c36a94190>],
#  'means': []}

# %%
df['acc'].describe()
# Out:
# count    45480.00000
# mean        -0.39304
# std          1.37694
# min        -13.48000
# 25%         -0.68000
# 50%         -0.16000
# 75%          0.24000
# max         18.50000
# Name: acc, dtype: float64

# %%
df2 = df[~df['acc'].between(-2.06, 1.62)]
df2
# Out:
#         obu_id  group_id veh_type   seq            timestamp             x  \
# 287    3602159         2       TW  3843  2020/10/06 21:24:58  954555.76300
# 288    3602159         2       TW  3842  2020/10/06 21:24:57  954549.72200
# 298    3602159         2       TW  3844  2020/10/06 21:24:59  954563.54100
# 330    3602159         2       TW  3812  2020/10/06 21:24:27  954367.81200
# 333    3602159         2       TW  3825  2020/10/06 21:24:40  954538.14100
# ...        ...       ...      ...   ...                  ...           ...
# 45360  4801715         0       TW   208  2020/10/06 17:14:41  954371.34500
# 45363  4801715         0       TW   205  2020/10/06 17:14:38  954371.34500
# 45364  4801715         0       TW   204  2020/10/06 17:14:37  954371.34500
# 45369  4801715         0       TW   211  2020/10/06 17:14:44  954371.34500
# 45370  4801715         0       TW   210  2020/10/06 17:14:43  954371.34500
#
# ...

# %%
dilemma2 = (1 + 16.67/(2*df2['acc']) + (51.8 + 5)/16.67 - 5)*16.67
dilemma2
# Out:
# 287       60.65018
# 288       62.86579
# 298       67.74260
# 330       73.82148
# 333      -69.51281
#            ...
# 45360    -24.69284
# 45363    -24.69284
# 45364    -24.69284
# 45369    -24.69284
# 45370    -24.69284
# Name: acc, Length: 3114, dtype: float64

# %%
dilemma2.describe()
# Out:
# count    3114.00000
# mean      -34.67609
# std        42.47574
# min       -77.00292
# 25%       -64.15518
# 50%       -43.60438
# 75%       -24.47501
# max        75.36199
# Name: acc, dtype: float64

# %%
plt.boxplot(dilemma2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c39d1eb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c39d44150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c39b79bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c39d45310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c39d45b90>],
#  'means': []}

# %%
df3 = df[~df['acc'].between(-4.82, 4.38)]
dilemma3 = (1 + 16.67/(2*df3['acc']) + (51.8 + 5)/16.67 - 5)*16.67
dilemma3
# Out:
# 853      -24.47501
# 854      -24.47501
# 855      -24.47501
# 856      -24.47501
# 857      -24.47501
#            ...
# 45360    -24.69284
# 45363    -24.69284
# 45364    -24.69284
# 45369    -24.69284
# 45370    -24.69284
# Name: acc, Length: 712, dtype: float64

# %%
dilemma3.describe()
# Out:
# count    712.00000
# mean     -28.21251
# std        5.50801
# min      -38.12074
# 25%      -34.51554
# 50%      -24.47501
# 75%      -24.47501
# max       -2.36949
# Name: acc, dtype: float64

# %%
plt.boxplot(dilemma3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c39f40610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c39f416d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c39f3bbd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c39f42750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c39f42e50>],
#  'means': []}

# %%
df4 = pd.read_csv('J:/hyorim/회현사거리/회현사거리동쪽딜레마.csv', encoding='euc-kr')
df4
# Out:
#        obu_id  group_id veh_type   seq            timestamp             x  \
# 0      290191         0       TW  1662  2020/10/03 11:51:43  954316.58100
# 1      290191         0       TW  1668  2020/10/03 11:51:49  954288.21300
# 2      290191         0       TW  1667  2020/10/03 11:51:48  954292.44800
# 3      290191         0       TW  1670  2020/10/03 11:51:51  954280.38800
# 4      290191         0       TW  1669  2020/10/03 11:51:50  954284.17800
# ...       ...       ...      ...   ...                  ...           ...
# 9838  4702285         0       TW  1974  2020/10/07 12:35:15  954277.56500
# 9839  4702285         0       TW  4072  2020/10/07 13:10:12  954280.10100
# 9840  4702285         0       TW  4071  2020/10/07 13:10:11  954278.24100
# 9841  4702285         0       TW  4182  2020/10/07 13:11:59  954318.34500
# 9842  4702285         0       TW  4181  2020/10/07 13:11:58  954311.98600
#
#                   y      spd       acc  type  ...    m_date  rc_id rc_name  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9843 entries, 0 to 9842
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   obu_id      9843 non-null   int64
#  1   group_id    9843 non-null   int64
#  2   veh_type    9843 non-null   object
#  3   seq         9843 non-null   int64
#  4   timestamp   9843 non-null   object
#  5   x           9843 non-null   float64
#  6   y           9843 non-null   float64
#  7   spd         9843 non-null   float64
#  8   acc         9843 non-null   float64
#  9   type        9843 non-null   int64
#  10  longitude   9843 non-null   float64
#  11  latitude    9843 non-null   float64
#  12  layer       9843 non-null   object
#  13  path        9843 non-null   object
#  14  link_id     9843 non-null   int64
#  15  up_f_node   9843 non-null   int64
#  16  up_t_node   9843 non-null   int64
#  17  dw_f_node   9843 non-null   int64
#  18  dw_t_node   9843 non-null   int64
# ...

# %%
df4['timestamp2'] = pd.to_datetime(df4['timestamp'])

# %%
df4
# Out:
#        obu_id  group_id veh_type   seq            timestamp             x  \
# 0      290191         0       TW  1662  2020/10/03 11:51:43  954316.58100
# 1      290191         0       TW  1668  2020/10/03 11:51:49  954288.21300
# 2      290191         0       TW  1667  2020/10/03 11:51:48  954292.44800
# 3      290191         0       TW  1670  2020/10/03 11:51:51  954280.38800
# 4      290191         0       TW  1669  2020/10/03 11:51:50  954284.17800
# ...       ...       ...      ...   ...                  ...           ...
# 9838  4702285         0       TW  1974  2020/10/07 12:35:15  954277.56500
# 9839  4702285         0       TW  4072  2020/10/07 13:10:12  954280.10100
# 9840  4702285         0       TW  4071  2020/10/07 13:10:11  954278.24100
# 9841  4702285         0       TW  4182  2020/10/07 13:11:59  954318.34500
# 9842  4702285         0       TW  4181  2020/10/07 13:11:58  954311.98600
#
#                   y      spd       acc  type  ...  rc_id  rc_name rc_hist  \
# ...

# %%
df4['agg'] = df4.timestamp2.resample('300T').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\hyorim\Desktop\공유드라이브\PythonQuery\SeoulTraffic\dilemma.ipynb Cell 21 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hyorim/Desktop/%EA%B3%B5%EC%9C%A0%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C/PythonQuery/SeoulTraffic/dilemma.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> df4['agg'] = df4.timestamp2.resample('300T').sum()
#
# File c:\Users\hyorim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:5872, in Series.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    5855 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5856 def resample(
#    5857     self,
#    (...)
#    5870     group_keys: bool | lib.NoDefault = no_default,
#    5871 ) -> Resampler:
# -> 5872     return super().resample(
# ...

# %%
df5 = df.resample(rule='300T').first()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\hyorim\Desktop\공유드라이브\PythonQuery\SeoulTraffic\dilemma.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hyorim/Desktop/%EA%B3%B5%EC%9C%A0%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C/PythonQuery/SeoulTraffic/dilemma.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> df5 = df.resample(rule='300T').first()
#
# File c:\Users\hyorim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11379, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#   11362 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   11363 def resample(
#   11364     self,
#    (...)
#   11377     group_keys: bool | lib.NoDefault = no_default,
#   11378 ) -> Resampler:
# > 11379     return super().resample(
#   11380         rule=rule,
# ...

# %%
import pandas as pd
from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files = os.listdir('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/')

# %%
files
# Out:
# ['경찰서eastbound.csv',
#  '경찰서northbound.csv',
#  '경찰서southbound.csv',
#  '경찰서westbound.csv',
#  '명보사거리eastbound.csv',
#  '명보사거리southbound.csv',
#  '명보사거리westbound.csv',
#  '을지로3가eastbound.csv',
#  '을지로3가southbound.csv',
#  '을지로3가westbound.csv',
#  '을지로4가eastbound.csv',
#  '을지로4가northbound.csv',
#  '을지로4가westbound.csv',
#  '을지로5가eastbound.csv',
#  '을지로5가northbound.csv',
#  '을지로5가southbound.csv',
#  '을지로5가westbound.csv']

# %%
df1 = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/경찰서southbound.csv')
df2 = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/경찰서westbound.csv')

# %%
df1
# Out:
#        obu_id  group_id veh_type   seq            timestamp             x  \
# 0      401244         0       TW  2547  2020/10/05 06:25:56  954982.51700
# 1      401244         0       TW  2548  2020/10/05 06:25:57  954986.70300
# 2      401244         0       TW  2549  2020/10/05 06:25:58  954990.35800
# 3      401244         0       TW  2550  2020/10/05 06:25:59  954993.55200
# 4      401244         0       TW  2551  2020/10/05 06:26:00  954996.49900
# ...       ...       ...      ...   ...                  ...           ...
# 6315  4801238         0       TW  3910  2020/10/30 11:12:28  955010.14300
# 6316  4801238         0       TW  3911  2020/10/30 11:12:29  955004.36000
# 6317  4801238         0       TW  3912  2020/10/30 11:12:30  954997.36400
# 6318  4801238         0       TW  3913  2020/10/30 11:12:31  954989.59200
# 6319  4801238         0       TW  3914  2020/10/30 11:12:32  954981.48100
#
#                   y      spd       acc  type  longitude  latitude  \
# ...

# %%
plt.boxplot(df1['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1feea593090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1feea2c1990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1feea4590d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1feea2907d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1feea24bb50>],
#  'means': []}

# %%
sns.histplot(df1['acc'])
# Out:
# <AxesSubplot: xlabel='acc', ylabel='Count'>

# %%
df1['acc'].describe()
# Out:
# count    6320.00000
# mean       -0.93647
# std         2.00045
# min       -10.85000
# 25%        -1.08000
# 50%        -0.49000
# 75%        -0.02000
# max         2.84000
# Name: acc, dtype: float64

# %%
len(df1[df1['acc'].between(-2,2)])/len(df1)
# Out:
# 0.9031645569620254

# %%
df3 = df1[df1['acc']<-2]
df3
# Out:
#        obu_id  group_id veh_type    seq            timestamp             x  \
# 70    4902202         0       TW   4227  2020/10/05 13:48:13  955006.65800
# 71    4902202         0       TW   4228  2020/10/05 13:48:14  955006.65800
# 72    4902202         0       TW   4229  2020/10/05 13:48:15  955006.65800
# 73    4902202         0       TW   4230  2020/10/05 13:48:16  955006.65800
# 74    4902202         0       TW   4231  2020/10/05 13:48:17  955006.65800
# ...       ...       ...      ...    ...                  ...           ...
# 4629  3001454         0       TW  11150  2020/10/23 18:32:13  955032.52800
# 4630  3001454         0       TW  11151  2020/10/23 18:32:14  955032.52800
# 4631  3001454         0       TW  11152  2020/10/23 18:32:15  955032.52800
# 4632  3001454         0       TW  11153  2020/10/23 18:32:16  955032.52800
# 4633  3001454         0       TW  11154  2020/10/23 18:32:17  955032.52800
#
#                   y      spd       acc  type  longitude  latitude  \
# ...

# %%
df3['acc'].describe()
# Out:
# count    606.00000
# mean      -6.16690
# std        2.63863
# min      -10.85000
# 25%       -7.68000
# 50%       -7.68000
# 75%       -3.94000
# max       -2.03000
# Name: acc, dtype: float64

# %%
dilemma = (1 + 16.67/(2*-6.16) + (25.2 + 5)/16.67 - 5)*16.67
dilemma
# Out:
# -59.035917207792224

# %%
df2['acc'].describe()
# Out:
# count    7917.00000
# mean       -0.90030
# std         1.91949
# min       -16.18000
# 25%        -1.05000
# 50%        -0.32000
# 75%         0.00000
# max         8.81000
# Name: acc, dtype: float64

# %%
sns.histplot(df2['acc'])
plt.xlim(-3,3)
# Out:
# (-3.0, 3.0)

# %%
len(df2[df2['acc'].between(-1,1)])/len(df1)
# Out:
# 0.9011075949367089

# %%
df4 = df2[df2['acc']<-1]
df4
# Out:
#        obu_id  group_id veh_type   seq            timestamp             x  \
# 121   1201289         0       TW  5731  2020/10/06 10:33:23  954836.16800
# 122   1201289         0       TW  5732  2020/10/06 10:33:24  954839.35500
# 123   1201289         0       TW  5733  2020/10/06 10:33:25  954841.33900
# 172    260645         0       TW  3735  2020/10/06 14:49:44  954808.99400
# 173    260645         0       TW  3736  2020/10/06 14:49:45  954808.99400
# ...       ...       ...      ...   ...                  ...           ...
# 7782  3401203         0       TW   381  2020/10/30 12:03:51  954811.77500
# 7783  3401203         0       TW   382  2020/10/30 12:03:52  954811.77500
# 7784  3401203         0       TW   383  2020/10/30 12:03:53  954811.77500
# 7785  3401203         0       TW   384  2020/10/30 12:03:54  954811.77500
# 7786  3401203         0       TW   385  2020/10/30 12:03:55  954811.77500
#
#                   y      spd       acc  type  longitude  latitude  \
# ...

# %%
df4['acc'].describe()
# Out:
# count    2049.00000
# mean       -3.20898
# std         2.49584
# min       -16.18000
# 25%        -3.22000
# 50%        -2.70000
# 75%        -1.38000
# max        -1.01000
# Name: acc, dtype: float64

# %%
dilemma = (1 + 16.67/(2*-3.20) + (25.2 + 5)/16.67 - 5)*16.67
dilemma
# Out:
# -79.900140625

# %%
sns.histplot(df1['spd'])
# Out:
# <AxesSubplot: xlabel='spd', ylabel='Count'>

# %%
df1['spd'].describe()
# Out:
# count    6320.00000
# mean        3.01656
# std         3.86211
# min         0.00000
# 25%         0.00000
# 50%         0.30000
# 75%         5.88000
# max        17.73000
# Name: spd, dtype: float64

# %%
a = df1['spd'].to_numpy()
np.percentile(a, 90)
# Out:
# 9.271000000000003

# %%
df5 = df1[df1['spd']>=9.27]
df5.describe()
# Out:
#               obu_id   group_id          seq             x              y  \
# count      635.00000  635.00000    635.00000     635.00000      635.00000
# mean   1939859.31339    0.22362   2575.54331  955056.86561  1951817.18216
# std    1634714.76058    0.48356   2788.64592      33.25224       10.46107
# min       3600.00000    0.00000      4.00000  954982.28100  1951796.46400
# 25%     380989.00000    0.00000    274.50000  955029.95700  1951808.81900
# 50%    1801235.00000    0.00000   1757.00000  955058.49900  1951816.41700
# 75%    3301279.00000    0.00000   3491.50000  955083.64600  1951824.86650
# max    4902011.00000    2.00000  11135.00000  955112.59300  1951849.33700
#
#              spd        acc       type  longitude   latitude    weekday  \
# count  635.00000  635.00000  635.00000  635.00000  635.00000  635.00000
# mean    10.94416    0.05394    1.30709  126.99110   37.56462    1.00000
# std      1.39331    0.67496    2.93922    0.00038    0.00009    0.00000
# ...

# %%
df7 = df1[(df1['spd']>=9.27)&(df1['acc']<0)]
df7.describe()
# Out:
#               obu_id   group_id          seq             x              y  \
# count      268.00000  268.00000    268.00000     268.00000      268.00000
# mean   2077022.49254    0.25373   2556.01866  955047.04892  1951819.54574
# std    1630004.34996    0.52910   2817.68943      32.05501       10.26837
# min       3600.00000    0.00000      4.00000  954982.28100  1951796.46400
# 25%     400123.00000    0.00000    231.25000  955023.50725  1951811.62975
# 50%    2102414.00000    0.00000   1728.50000  955045.08700  1951819.73650
# 75%    3401193.25000    0.00000   3666.00000  955071.80775  1951826.52950
# max    4901858.00000    2.00000  11135.00000  955112.50600  1951849.33700
#
#              spd        acc       type  longitude   latitude    weekday  \
# count  268.00000  268.00000  268.00000  268.00000  268.00000  268.00000
# mean    10.96537   -0.49474    1.60075  126.99099   37.56464    1.00000
# std      1.40451    0.61023    4.06606    0.00036    0.00009    0.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-0.49474) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -300.6533722763473

# %%
dilemma = (1 + 16.67/(2*0.09) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# 1524.0172222222227

# %%
df6 = df1[(df1['acc']<-2)&(df1['spd']>=9.27)]
df6.describe()
# Out:
#               obu_id  group_id        seq             x              y  \
# count        4.00000   4.00000    4.00000       4.00000        4.00000
# mean   3901542.00000   0.00000  314.50000  955040.78025  1951827.67875
# std     923753.50250   0.00000  357.95763      55.92687       16.47683
# min    3101548.00000   0.00000    4.00000  954991.36900  1951809.91400
# 25%    3101548.00000   0.00000    4.75000  954992.93350  1951816.43750
# 50%    3901542.00000   0.00000  314.50000  955039.59450  1951827.19100
# 75%    4701536.00000   0.00000  624.25000  955087.44125  1951838.43225
# max    4701536.00000   0.00000  625.00000  955092.56300  1951846.41900
#
#             spd       acc      type  longitude  latitude  weekday  saturday  \
# count   4.00000   4.00000   4.00000    4.00000   4.00000  4.00000   4.00000
# mean   13.37750  -4.23000  16.50000  126.99092  37.56471  1.00000   0.00000
# std     2.85312   1.52528  16.74316    0.00063   0.00015  0.00000   0.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-4.56) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -50.280274122807036

# %%
b = df1['spd'].to_numpy()
np.percentile(a, 50)
# Out:
# 0.3

# %%
df5 = df1[df1['spd']>=0.3]
df5.describe()
# Out:
#               obu_id    group_id          seq             x              y  \
# count     3161.00000  3161.00000   3161.00000    3161.00000     3161.00000
# mean   1755557.56817     0.19899   2526.05568  955035.51290  1951823.23357
# std    1603662.51268     0.56081   2820.34665      38.09918       12.02215
# min       3600.00000     0.00000      4.00000  954981.07300  1951796.14400
# 25%     302045.00000     0.00000    387.00000  955003.46000  1951813.45500
# 50%    1301307.00000     0.00000   1700.00000  955026.69900  1951825.14100
# 75%    3202033.00000     0.00000   3491.00000  955066.48100  1951832.64200
# max    5001981.00000     5.00000  12968.00000  955112.96500  1951850.51600
#
#               spd         acc        type   longitude    latitude     weekday  \
# count  3161.00000  3161.00000  3161.00000  3161.00000  3161.00000  3161.00000
# mean      6.02906    -0.05267     7.49541   126.99086    37.56467     1.00000
# ...

# %%
df6 = df1[(df1['acc']<0)&(df1['spd']>=0.3)]
df6.describe()
# Out:
#               obu_id    group_id          seq             x              y  \
# count     1632.00000  1632.00000   1632.00000    1632.00000     1632.00000
# mean   1808536.18811     0.24142   2469.53860  955032.09772  1951824.06589
# std    1616878.44266     0.65926   2755.36929      34.18384       11.16629
# min       3600.00000     0.00000      4.00000  954981.07300  1951796.46400
# 25%     320726.00000     0.00000    354.75000  955004.88300  1951816.35575
# 50%    1501167.00000     0.00000   1688.50000  955025.36150  1951825.35000
# 75%    3301279.00000     0.00000   3580.25000  955055.27550  1951832.28000
# max    5001981.00000     5.00000  12966.00000  955112.50600  1951850.32100
#
#               spd         acc        type   longitude    latitude     weekday  \
# count  1632.00000  1632.00000  1632.00000  1632.00000  1632.00000  1632.00000
# mean      5.73532    -0.56281     8.08272   126.99082    37.56468     1.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-0.47) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -315.4364893617022

# %%
b = df1['spd'].to_numpy()
c = np.percentile(a, 50)
df5 = df1[df1['spd']>=c]
df5.describe()
df6 = df1[(df1['acc']<0)&(df1['spd']>=c)]
df6.describe()
# Out:
#               obu_id    group_id          seq             x              y  \
# count     1632.00000  1632.00000   1632.00000    1632.00000     1632.00000
# mean   1808536.18811     0.24142   2469.53860  955032.09772  1951824.06589
# std    1616878.44266     0.65926   2755.36929      34.18384       11.16629
# min       3600.00000     0.00000      4.00000  954981.07300  1951796.46400
# 25%     320726.00000     0.00000    354.75000  955004.88300  1951816.35575
# 50%    1501167.00000     0.00000   1688.50000  955025.36150  1951825.35000
# 75%    3301279.00000     0.00000   3580.25000  955055.27550  1951832.28000
# max    5001981.00000     5.00000  12966.00000  955112.50600  1951850.32100
#
#               spd         acc        type   longitude    latitude     weekday  \
# count  1632.00000  1632.00000  1632.00000  1632.00000  1632.00000  1632.00000
# mean      5.73532    -0.56281     8.08272   126.99082    37.56468     1.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-0.47000) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -315.4364893617022

# %%
c
# Out:
# 7.57

# %%
df2[df2['spd']>=c].describe()
# Out:
#               obu_id   group_id          seq             x              y  \
# count      793.00000  793.00000    793.00000     793.00000      793.00000
# mean   2122980.23455    0.31148   2244.74779  954878.41734  1951825.36785
# std    1609798.42022    0.74710   2941.68380      35.32026       10.14346
# min       1201.00000    0.00000      2.00000  954802.85800  1951797.81500
# 25%     440279.00000    0.00000    173.00000  954852.21600  1951817.82900
# 50%    2002352.00000    0.00000    955.00000  954883.14500  1951826.01200
# 75%    3402138.00000    0.00000   3105.00000  954906.39600  1951833.07400
# max    5001981.00000    5.00000  12637.00000  954936.71200  1951846.24600
#
#              spd        acc       type  longitude   latitude    weekday  \
# count  793.00000  793.00000  793.00000  793.00000  793.00000  793.00000
# mean     9.25758    0.10343    1.51576  126.98908   37.56469    1.00000
# std      7.73819    0.77295    4.01010    0.00040    0.00009    0.00000
# ...

# %%
sns.histplot(df6['acc'])
# Out:
# <AxesSubplot: xlabel='acc', ylabel='Count'>

# %%
b = df1['spd'].to_numpy()
c = np.percentile(b, 60)
# df5 = df2[df2['spd']>=c]
# df5.describe()
df6 = df1[(df1['acc']<0)&(df1['spd']>=c)]
df6.describe()
# Out:
#               obu_id    group_id          seq             x              y  \
# count     1094.00000  1094.00000   1094.00000    1094.00000     1094.00000
# mean   1611604.23309     0.45887   2838.08684  954973.52671  1951758.23436
# std    1546926.83083     0.87229   3024.55633       6.32243       30.45351
# min       4063.00000     0.00000     18.00000  954957.74900  1951698.93200
# 25%     270503.00000     0.00000    665.25000  954968.77575  1951734.87100
# 50%     901196.00000     0.00000   1967.50000  954973.46550  1951761.57600
# 75%    2801870.00000     1.00000   3664.75000  954978.13150  1951780.12900
# max    4902226.00000     5.00000  19697.00000  954990.99200  1951818.37200
#
#               spd         acc        type   longitude    latitude     weekday  \
# count  1094.00000  1094.00000  1094.00000  1094.00000  1094.00000  1094.00000
# mean      6.88264    -0.47312     3.05027   126.99016    37.56408     1.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-0.37500) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -390.3285333333334

# %%
df5.describe()
# Out:
#               obu_id    group_id          seq             x              y  \
# count     3161.00000  3161.00000   3161.00000    3161.00000     3161.00000
# mean   1755557.56817     0.19899   2526.05568  955035.51290  1951823.23357
# std    1603662.51268     0.56081   2820.34665      38.09918       12.02215
# min       3600.00000     0.00000      4.00000  954981.07300  1951796.14400
# 25%     302045.00000     0.00000    387.00000  955003.46000  1951813.45500
# 50%    1301307.00000     0.00000   1700.00000  955026.69900  1951825.14100
# 75%    3202033.00000     0.00000   3491.00000  955066.48100  1951832.64200
# max    5001981.00000     5.00000  12968.00000  955112.96500  1951850.51600
#
#               spd         acc        type   longitude    latitude     weekday  \
# count  3161.00000  3161.00000  3161.00000  3161.00000  3161.00000  3161.00000
# mean      6.02906    -0.05267     7.49541   126.99086    37.56467     1.00000
# ...

# %%
dilemma = (1 + 16.67/(2*-0.02000) + (25.2 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# -6967.032500000002

# %%
# sns.lineplot(df1['spd'])//
sns.histplot(data=df1, x="spd")
sns.histplot(data=df2, x="spd")
plt.legend()
plt.xlim(0,20)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (0.0, 20.0)

# %%
for file in files:
    df = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/'+file)
    sns.histplot(data=df, x="acc")

plt.xlim(-15,5)
# Out:
# (-15.0, 5.0)

# %%
for file in files:
    df = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/'+file)
    sns.histplot(data=df, x="spd")

plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %%
df['spd'].describe()
# Out:
# count    47430.000000
# mean         4.408647
# std          4.313527
# min          0.000000
# 25%          0.000000
# 50%          3.620000
# 75%          7.580000
# max         21.710000
# Name: spd, dtype: float64

# %%
df1['acc'].describe()
# Out:
# count    6320.000000
# mean       -0.936467
# std         2.000454
# min       -10.850000
# 25%        -1.080000
# 50%        -0.490000
# 75%        -0.020000
# max         2.840000
# Name: acc, dtype: float64

# %%
plt.boxplot(df1['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14391917810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1438f26d650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14386a0ab10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1438f26dc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1438f26d3d0>],
#  'means': []}

# %%
plt.boxplot(df['spd'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1438b29aa50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1438b2a8310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1438b2a2890>],
#  'medians': [<matplotlib.lines.Line2D at 0x1438b2a92d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1438b2a3f90>],
#  'means': []}

# %%
df5 = df[df['spd'] > 7.580000]
plt.boxplot(df5['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14386eeecd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14388ce44d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14386eef250>],
#  'medians': [<matplotlib.lines.Line2D at 0x14388ce4dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14386eeca90>],
#  'means': []}

# %%
df3 = df[df['spd'] > 7.5]
plt.boxplot(df3['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x143870e9910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x143870eaad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x143870e91d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x143870ebad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14389c54310>],
#  'means': []}

# %%
df4 = df3[df3['acc']<0]
plt.boxplot(df4['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1438aeb4c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1438aeb6010>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1438aeaa8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1438aeb6e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1438aeb7550>],
#  'means': []}

# %%
df6 = df[df['acc']> 2.5]

# %%
df7 = df1[df1['acc']<-2.5]

# %%
dilemma = (1 + 16.67/(2*df6['acc']) + (25.2 + 5)/16.67 - 5)*16.67
dilemma
# Out:
# 4538     10.302643
# 4539     17.166506
# 7520      1.902445
# 9561     10.460693
# 9562      2.659282
# 9563      9.834817
# 12042    17.374438
# 15572    -7.351184
# 17341    16.755421
# 18964    11.103716
# 18965    13.680451
# 19134     8.631834
# 19135    17.374438
# 21193    18.876355
# 21194    12.966423
# 21195    15.172212
# 21416     5.752356
# 21417     4.995955
# 21418    18.222539
# 22302    -0.202076
# 23578    10.302643
# 24909    18.008020
# 24910    16.150473
# 26547   -22.459369
# 27182     5.370738
# 29446    12.101976
# 29447     8.631834
# 29448    14.415403
# 31194    15.951868
# 32241    13.862192
# 33063     9.376254
# 33064    11.431879
# 33483    16.552233
# 37686   -11.032299
# 39704     6.804875
# 39705    11.597664
# 43880     6.804875
# 43881    12.101976
# 44647     1.276644
# 44648     2.223189
# 44649    10.302643
# 44809    16.350589
# 46544     2.440014
# 46545    17.166506
# Name: acc, dtype: float64

# %%
plt.boxplot(dilemma)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1438b6faa50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x143864edf10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1438c0e6090>],
#  'medians': [<matplotlib.lines.Line2D at 0x1438a3fd410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1438a3fc110>],
#  'means': []}

# %%
plt.boxplot(df6['acc'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14386e16550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14386e149d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1438ac67190>],
#  'medians': [<matplotlib.lines.Line2D at 0x14386e17c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14386e15ad0>],
#  'means': []}

# %%
dilemma.describe()
# Out:
# count    479.000000
# mean     -57.561537
# std        7.059396
# min      -83.901314
# 25%      -58.746739
# 50%      -54.571725
# 75%      -54.571725
# max      -49.285940
# Name: acc, dtype: float64

# %%
df
# Out:
#         obu_id  group_id veh_type    seq            timestamp           x  \
# 0        10237         0       TW    213  2020/10/05 11:20:29  955876.785
# 1        10237         0       TW    214  2020/10/05 11:20:30  955880.682
# 2        10237         0       TW    215  2020/10/05 11:20:31  955884.160
# 3        10237         0       TW    216  2020/10/05 11:20:32  955887.300
# 4        10237         0       TW    217  2020/10/05 11:20:33  955890.289
# ...        ...       ...      ...    ...                  ...         ...
# 47425  5002394         0       TW  11420  2020/10/30 17:45:18  955968.883
# 47426  5002394         0       TW  11421  2020/10/30 17:45:19  955973.101
# 47427  5002394         0       TW  11422  2020/10/30 17:45:20  955976.434
# 47428  5002394         0       TW  11423  2020/10/30 17:45:21  955978.930
# 47429  5002394         0       TW  11424  2020/10/30 17:45:22  955980.662
#
#                  y   spd   acc  type   longitude   latitude  \
# ...

# %%
plt.boxplot(df['spd'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14388eb8610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14388eb82d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14388ebb890>],
#  'medians': [<matplotlib.lines.Line2D at 0x14388eb8b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14387051b50>],
#  'means': []}

# %% [markdown]
# ====

# %%
df1 = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/경찰서southbound.csv')
df2 = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/경찰서westbound.csv')

# %%
df1
# Out:
#        obu_id  group_id veh_type  seq            timestamp             x  \
# 0      201511         0       TW  651  2020/10/05 11:47:22  954964.25200
# 1      201511         0       TW  652  2020/10/05 11:47:23  954973.62200
# 2      100331         0       TW    5  2020/10/05 12:06:58  954969.59200
# 3      100331         0       TW    6  2020/10/05 12:06:59  954968.73900
# 4      100331         0       TW    7  2020/10/05 12:07:00  954967.88600
# ...       ...       ...      ...  ...                  ...           ...
# 5461  4801388         0       TW  355  2020/10/30 08:44:41  954985.12900
# 5462  4801388         0       TW  356  2020/10/30 08:44:42  954985.33800
# 5463  4801388         0       TW  357  2020/10/30 08:44:43  954985.30700
# 5464  4801388         0       TW  358  2020/10/30 08:44:44  954985.11500
# 5465  4801388         0       TW  359  2020/10/30 08:44:45  954984.98200
#
#                   y      spd       acc  type  longitude  latitude  \
# ...

# %%
sns.histplot(df1.spd)
# Out:
# <AxesSubplot: xlabel='spd', ylabel='Count'>

# %%
sns.histplot(df1.spd)
plt.ylim(0,600)
plt.xlim(5,)
# Out:
# (5.0, 16.4535)

# %%
sample = df1[df1.spd >= 5]
sns.histplot(sample.spd)
# Out:
# <AxesSubplot: xlabel='spd', ylabel='Count'>

# %%
sns.boxplot(sample.spd)
# Out:
# <AxesSubplot: >

# %%
sample.spd.describe()
# Out:
# count    2059.00000
# mean        6.99603
# std         1.60641
# min         5.00000
# 25%         5.81000
# 50%         6.66000
# 75%         7.83000
# max        15.67000
# Name: spd, dtype: float64

# %%
sns.histplot(sample.acc)
# Out:
# <AxesSubplot: xlabel='acc', ylabel='Count'>

# %%
sample_acc = sample[sample['acc']<-1]
sns.histplot(sample_acc.acc)
# Out:
# <AxesSubplot: xlabel='acc', ylabel='Count'>

# %%
sample_acc.spd.describe()
# Out:
# count    106.00000
# mean       7.62066
# std        2.02378
# min        5.00000
# 25%        6.08750
# 50%        7.11000
# 75%        8.59000
# max       15.67000
# Name: spd, dtype: float64

# %%
dilemma = (1 + sample_acc.spd/(2*sample_acc.acc) + (29.1 + 5)/16.67 - 4)*16.67
dilemma
# Out:
# 138     -82.43565
# 139     -66.46656
# 140     -65.21893
# 258     -58.86214
# 259     -50.18352
#           ...
# 5331    -56.75839
# 5363    -67.03133
# 5429    -89.83444
# 5430    -63.33732
# 5431    -57.83381
# Length: 106, dtype: float64

# %%
sns.histplot(dilemma)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
df1.timestamp2[0][-8:]
# Out:
# '11:47:22'

# %%
signal = pd.read_csv('D:/서울시신호/데이터/신호주기(한양도성)/DB/중부경찰서앞_20191219_TOD1.csv')

# %%
signal
# Out:
#               시간  TOD  패턴  현시  연동   주기      기준  좌회전신호  비보호좌회전신호  직진신호  ...  \
# 0        0:00:00    1   1   1  10  100  을지로3가역      0         0     0  ...
# 1        0:00:01    1   1   1  10  100  을지로3가역      0         0     0  ...
# 2        0:00:02    1   1   1  10  100  을지로3가역      0         0     0  ...
# 3        0:00:03    1   1   1  10  100  을지로3가역      0         0     0  ...
# 4        0:00:04    1   1   1  10  100  을지로3가역      0         0     0  ...
# ...          ...  ...  ..  ..  ..  ...     ...    ...       ...   ...  ...
# 345595  23:59:55    1   4   2  10  110    명동성당      0         0     0  ...
# 345596  23:59:56    1   4   2  10  110    명동성당      0         0     0  ...
# 345597  23:59:57    1   4   2  10  110    명동성당      0         0     0  ...
# 345598  23:59:58    1   4   2  10  110    명동성당      0         0     0  ...
# 345599  23:59:59    1   4   2  10  110    명동성당      0         0     0  ...
#
# ...

# %%
signal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345600 entries, 0 to 345599
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   시간           345600 non-null  object
#  1   TOD          345600 non-null  int64
#  2   패턴           345600 non-null  int64
#  3   현시           345600 non-null  int64
#  4   연동           345600 non-null  int64
#  5   주기           345600 non-null  int64
#  6   기준           345600 non-null  object
#  7   좌회전신호        345600 non-null  int64
#  8   비보호좌회전신호     345600 non-null  int64
#  9   직진신호         345600 non-null  int64
#  10  적색신호         345600 non-null  int64
#  11  황색신호         345600 non-null  int64
#  12  보행신호         345600 non-null  int64
#  13  기준link       345600 non-null  int64
#  14  보행자좌회전상충     345600 non-null  int64
#  15  보행자직진상충      345600 non-null  int64
#  16  보행자우회전상충     345600 non-null  int64
#  17  보행자비보호좌회전상충  345600 non-null  int64
# ...

# %%
yellow = signal[(signal['황색신호'] == 1) & (signal.기준 == '퇴계로2가')].reset_index()
yellow
# Out:
#        index        시간  TOD  패턴  현시  연동   주기     기준  좌회전신호  비보호좌회전신호  ...  \
# 0     172822   0:00:22    1   1   1  10  100  퇴계로2가      0         0  ...
# 1     172823   0:00:23    1   1   1  10  100  퇴계로2가      0         0  ...
# 2     172824   0:00:24    1   1   1  10  100  퇴계로2가      0         0  ...
# 3     172825   0:00:25    1   1   1  10  100  퇴계로2가      0         0  ...
# 4     172922   0:02:02    1   1   1  10  100  퇴계로2가      0         0  ...
# ...      ...       ...  ...  ..  ..  ..  ...    ...    ...       ...  ...
# 3067  259070  23:57:50    1   4   1  10  110  퇴계로2가      0         0  ...
# 3068  259177  23:59:37    1   4   1  10  110  퇴계로2가      0         0  ...
# 3069  259178  23:59:38    1   4   1  10  110  퇴계로2가      0         0  ...
# 3070  259179  23:59:39    1   4   1  10  110  퇴계로2가      0         0  ...
# 3071  259180  23:59:40    1   4   1  10  110  퇴계로2가      0         0  ...
#
#       보행신호     기준link  보행자좌회전상충  보행자직진상충  보행자우회전상충  보행자비보호좌회전상충  차량좌회전상충  \
# ...

# %%
df1['timestamp'][0][-8:]
# Out:
# '11:47:22'

# %%
pd.to_datetime(yellow['시간'][0])
# Out:
# Timestamp('2023-08-01 00:00:22')

# %%
df1['timestamp2'][0][-8:] in yellow.시간
# Out:
# False

# %%
def is_yellow(data):
    if data[-8] == 0:
        if data[-7:] in yellow.시간:
            return 1
    elif data[-8:] in yellow.시간:
        return 1
    else:
        return 0

# %%
df1['yellow'] = df1['timestamp'].apply(is_yellow)
df1
# Out:
#        obu_id  group_id veh_type  seq            timestamp             x  \
# 0      201511         0       TW  651  2020/10/05 11:47:22  954964.25200
# 1      201511         0       TW  652  2020/10/05 11:47:23  954973.62200
# 2      100331         0       TW    5  2020/10/05 12:06:58  954969.59200
# 3      100331         0       TW    6  2020/10/05 12:06:59  954968.73900
# 4      100331         0       TW    7  2020/10/05 12:07:00  954967.88600
# ...       ...       ...      ...  ...                  ...           ...
# 5461  4801388         0       TW  355  2020/10/30 08:44:41  954985.12900
# 5462  4801388         0       TW  356  2020/10/30 08:44:42  954985.33800
# 5463  4801388         0       TW  357  2020/10/30 08:44:43  954985.30700
# 5464  4801388         0       TW  358  2020/10/30 08:44:44  954985.11500
# 5465  4801388         0       TW  359  2020/10/30 08:44:45  954984.98200
#
#                   y      spd       acc  type  longitude  latitude  \
# ...

# %%
df1_y = df1[df1.yellow == 1]

# %%
df1_y
# Out:
# Empty DataFrame
# Columns: [obu_id, group_id, veh_type, seq, timestamp, x, y, spd, acc, type, longitude, latitude, timestamp2, weekday, saturday, sunday, holiday, yellow]
# Index: []

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('D:/서울시신호/데이터/GIS/한양도성/딜레마존초록/전체.csv', encoding='cp949')
df
# Out:
#          obu_id  group_id veh_type   seq         timestamp           x  \
# 0         10237         0       TW   213  2020-10-05 11:20  955876.785
# 1         10237         0       TW   214  2020-10-05 11:20  955880.682
# 2         10237         0       TW   215  2020-10-05 11:20  955884.160
# 3         10237         0       TW   216  2020-10-05 11:20  955887.300
# 4         10237         0       TW   217  2020-10-05 11:20  955890.289
# ...         ...       ...      ...   ...               ...         ...
# 426389  4801238         0       TW  3910  2020-10-30 11:12  955010.143
# 426390  4801238         0       TW  3911  2020-10-30 11:12  955004.360
# 426391  4801238         0       TW  3912  2020-10-30 11:12  954997.364
# 426392  4801238         0       TW  3913  2020-10-30 11:12  954989.592
# 426393  4801238         0       TW  3914  2020-10-30 11:12  954981.481
#
#                   y   spd   acc  type   longitude   latitude  \
# ...

# %%
df.pivot('spd', 'acc')
# Out:
# C:\Users\hyorim\AppData\Local\Temp\ipykernel_33884\279075232.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df.pivot('spd', 'acc')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\hyorim\Desktop\공유드라이브\PythonQuery\SeoulTraffic\dilemma.ipynb Cell 109 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hyorim/Desktop/%EA%B3%B5%EC%9C%A0%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C/PythonQuery/SeoulTraffic/dilemma.ipynb#Y220sZmlsZQ%3D%3D?line=0'>1</a> df.pivot('spd', 'acc')
#
# File c:\Users\hyorim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
df = df[df['spd']<100]

# %%
plt.scatter(df.spd, df.acc)

# %%
sns.heatmap(df[['spd', 'acc']])
# Out:
# <AxesSubplot: >

# %%
df2 = pd.read_csv('J:/서울dtg/SEOUL_TW_PS_20210707.csv')
df2
# Out:
#            obu_id  group_id veh_type   seq   timestamp           x  \
# 0           10651         0       TW     1  1594068307  964490.420
# 1           10651         0       TW     2  1594068308  964497.791
# 2           10651         0       TW     3  1594068309  964505.306
# 3           10651         0       TW     4  1594068310  964513.264
# 4           10651         0       TW     5  1594068311  964521.369
# ...           ...       ...      ...   ...         ...         ...
# 43775818  5002271         0       TW  1446  1594112578  926019.676
# 43775819  5002271         0       TW  1447  1594112579  926017.898
# 43775820  5002271         0       TW  1448  1594112580  926017.898
# 43775821  5002271         0       TW  1449  1594112581  926017.898
# 43775822  5002271         0       TW  1450  1594112582  926017.898
#
#                     y   spd   acc  type
# 0         1940947.762  0.00  0.00     0
# 1         1940948.100  7.38  7.38     0
# ...

# %%
plt.scatter(df2.spd, df2.acc)

# %%
plt.boxplot(df2.spd)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2221069f590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x222106c8250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x222106af610>],
#  'medians': [<matplotlib.lines.Line2D at 0x222106c9490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x222106c9c90>],
#  'means': []}

# %%
plt.boxplot(df2.acc)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2221071f650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22210728950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2221071eed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22210729a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2221072a0d0>],
#  'means': []}

# %%
df3 = pd.read_csv('J:/티맵포인트/p_reqdate=20220411_hanyang.csv', encoding='cp949')
df3
# Out:
#          p_reqdate      trip_init_session_id  mesh_cd  link_id  link_dir  \
# 0         20220411  105020220411052621740S00     5717    43485         0
# 1         20220411  105020220411052621740S00     5717    43485         0
# 2         20220411  105020220411052621740S00     5717    43485         0
# 3         20220411  105020220411052621740S00     5717    43485         0
# 4         20220411  105020220411052621740S00     5717    43485         0
# ...            ...                       ...      ...      ...       ...
# 1649655   20220411  355220220411113849962S00     5717    16365         1
# 1649656   20220411  355220220411113849962S00     5717    16365         1
# 1649657   20220411  355220220411113849962S00     5717    42799         0
# 1649658   20220411  355220220411113849962S00     5717    43442         0
# 1649659   20220411  355220220411113849962S00     5717    43441         1
#
#               gps_x      gps_y          gps_tm  speed_gps  altitude  ...  \
# ...

# %%
plt.boxplot(df2.spd)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x222108a4dd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x222108a5990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x222108935d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x222108a4810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x222108a7050>],
#  'means': []}

# %%
df2.spd.describe()
# Out:
# count    4.377582e+07
# mean     9.243784e+00
# std      9.060525e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      6.920000e+00
# 75%      1.570000e+01
# max      5.037800e+02
# Name: spd, dtype: float64
