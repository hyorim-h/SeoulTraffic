# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import os

# %%
os.chdir('J:\\링크경로한양도성')
os.getcwd()
# Out:
# 'J:\\링크경로한양도성'

# %%
agg_60 = os.listdir('tm_60_agg')
agg_60
# Out:
# ['tm_14T00_00.csv',
#  'tm_14T01_00.csv',
#  'tm_14T02_00.csv',
#  'tm_14T03_00.csv',
#  'tm_14T04_00.csv',
#  'tm_14T05_00.csv',
#  'tm_14T06_00.csv',
#  'tm_14T07_00.csv',
#  'tm_14T08_00.csv',
#  'tm_14T09_00.csv',
#  'tm_14T10_00.csv',
#  'tm_14T11_00.csv',
#  'tm_14T12_00.csv',
#  'tm_14T13_00.csv',
#  'tm_14T14_00.csv',
#  'tm_14T15_00.csv',
#  'tm_14T16_00.csv',
#  'tm_14T17_00.csv',
#  'tm_14T18_00.csv',
#  'tm_14T19_00.csv',
#  'tm_14T20_00.csv',
#  'tm_14T21_00.csv',
#  'tm_14T22_00.csv',
#  'tm_14T23_00.csv',
#  'tm_15T00_00.csv']

# %%
plt.ioff()

for i in agg_60[:-1]:
    tmp = pd.read_csv('tm_60_agg/' + i)
    print(i)
    plt.figure()
    plt.scatter(tmp.obu_id, tmp.speed, s=5)
    plt.xlabel('# of path usage')
    plt.ylabel('avg. speed')
    plt.title(i[6:11])
    plt.savefig('tm_60_agg_cntspeed/'+i[6:11]+'.png')
    plt.close()
# Out:
# tm_14T00_00.csv
# tm_14T01_00.csv
# tm_14T02_00.csv
# tm_14T03_00.csv
# tm_14T04_00.csv
# tm_14T05_00.csv
# tm_14T06_00.csv
# tm_14T07_00.csv
# tm_14T08_00.csv
# tm_14T09_00.csv
# tm_14T10_00.csv
# tm_14T11_00.csv
# tm_14T12_00.csv
# tm_14T13_00.csv
# tm_14T14_00.csv
# tm_14T15_00.csv
# tm_14T16_00.csv
# tm_14T17_00.csv
# tm_14T18_00.csv
# tm_14T19_00.csv
# tm_14T20_00.csv
# tm_14T21_00.csv
# tm_14T22_00.csv
# tm_14T23_00.csv

# %%
df3 = pd.read_csv('tm_60_agg/tm_14T14_00.csv')
df3
# Out:
#       v_from_link_id     v_link_id  v_to_link_id  obu_id       speed
# 0       4.346149e+10  4.346149e+10  4.346149e+10       1   88.200000
# 1       4.346149e+10  4.346150e+10  4.346150e+10       1   79.400000
# 2       4.346150e+10  4.346163e+10  4.346163e+10       1   40.595745
# 3       4.346150e+10  4.346150e+10  4.346163e+10       1   63.490909
# 4       4.346155e+10  4.346123e+10  4.346162e+10       1   85.200000
# ...              ...           ...           ...     ...         ...
# 1289    7.718007e+10  7.718007e+10  7.718007e+10       1  105.442991
# 1290    7.718007e+10  7.718007e+10  7.718007e+10       1  105.300000
# 1291    7.718007e+10  7.718007e+10  7.718000e+10       1  103.200000
# 1292    9.216018e+10  7.416018e+10  7.416029e+10       1   84.917647
# 1293    9.256010e+10  5.456051e+10  5.456051e+10       1   68.160000
#
# [1294 rows x 5 columns]

# %%
plt.scatter(df.obu_id, df.speed, s=5)
plt.xlabel('# of path usage')
plt.ylabel('avg. speed')
# plt.xlim(0,600)
# Out:
# Text(0, 0.5, 'avg. speed')

# %%
plt.scatter(df3.obu_id, df3.speed, s=5)
plt.xlabel('# of path usage')
plt.ylabel('avg. speed')
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %%
df4 = pd.read_csv('tm_60_agg/tm_14T06_00.csv')
df5 = pd.read_csv('tm_60_agg/tm_14T22_00.csv')

# %%
plt.scatter(df2.obu_id, df2.speed, s=5, alpha=0.4, c='gray')
plt.scatter(df4.obu_id, df4.speed, s=5, alpha=0.7, c='pink')
plt.scatter(df5.obu_id, df5.speed, s=5, alpha=0.5, c='brown')
plt.scatter(df.obu_id, df.speed, s=5, alpha=0.3, c='green')


plt.scatter(df3.obu_id, df3.speed, s=5, alpha=0.5, c='purple')
# plt.legend()
plt.xlabel('# of path usage')
plt.ylabel('avg. speed')
plt.show()
